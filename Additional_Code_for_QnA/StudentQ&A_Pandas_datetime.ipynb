# %%
import pandas as pd
import numpy as np

# %%
month = ["1990/08", "1990/10", "1990/10", "1990/10"]
CommunityDistrict = [3,3,2,7]

df = pd.DataFrame({"Month":month, "CommunityDistrict":CommunityDistrict})
df.head()
# Out:
#      Month  CommunityDistrict
# 0  1990/08                  3
# 1  1990/10                  3
# 2  1990/10                  2
# 3  1990/10                  7

# %%
df['year'] = pd.DatetimeIndex(df['Month']).year

# %%
df['month'] = pd.DatetimeIndex(df['Month']).year

# %%
df.head()
# Out:
#      Month  CommunityDistrict  year  month
# 0  1990/08                  3  1990   1990
# 1  1990/10                  3  1990   1990
# 2  1990/10                  2  1990   1990
# 3  1990/10                  7  1990   1990
