# %% [markdown]
# <a href="https://colab.research.google.com/github/YounSooKimTech/Greg_Python/blob/main/Q%26A_11_01_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import division
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import os
import matplotlib.pyplot as plt

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/YounSooKimTech/Greg_Python/main/Data/GSS.2006.csv")
df.head()
# Out:
#    vpsu  vstrat  adults  ballot  dateintv  famgen  form  formwt  gender1  \
# 0     1    1957       1       3       316       2     1       1        2
# 1     1    1957       2       2       630       1     2       1        2
# 2     1    1957       2       2       314       2     1       1        2
# 3     1    1957       1       1       313       1     2       1        2
# 4     1    1957       3       1       322       2     2       1        2
#
#    hompop  ...  away7  gender14  old14  relate14  relhh14  relhhd14  relsp14  \
# 0       3  ...    NaN       NaN    NaN       NaN      NaN       NaN      NaN
# 1       2  ...    NaN       NaN    NaN       NaN      NaN       NaN      NaN
# 2       2  ...    NaN       NaN    NaN       NaN      NaN       NaN      NaN
# 3       1  ...    NaN       NaN    NaN       NaN      NaN       NaN      NaN
# 4       3  ...    NaN       NaN    NaN       NaN      NaN       NaN      NaN
#
#    where12  where6  where7
# 0      NaN     NaN     NaN
# ...

# %%
df['realinc1000s'] = (df['realinc'])/1000

# %%
gg = df.dropna(subset = ["big5c2"])
lm_rep = smf.ols(formula = 'finrela~realinc1000s', data = gg).fit()
print (lm_rep.summary())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-956b943b1375> in <module>
#       1 gg = df.dropna(subset = ["big5c2"])
# ----> 2 lm_rep = smf.ols(formula = 'finrela~realinc1000s', data = gg).fit()
#       3 print (lm_rep.summary())
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py in from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     193                        'formula': formula,  # attach formula for unpckling
#     194                        'design_info': design_info})
# --> 195         mod = cls(endog, exog, *args, **kwargs)
#     196         mod.formula = formula
#     197
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     871                  **kwargs):
# ...

# %%
gg[["finrela", "realinc1000s"]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1515 entries, 7 to 4507
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   finrela       0 non-null      float64
#  1   realinc1000s  1294 non-null   float64
# dtypes: float64(2)
# memory usage: 35.5 KB

# %%
gg = df.dropna(subset = ['finrela'])
lm_rep = smf.ols(formula = 'finrela~realinc1000s', data = gg).fit()
print (lm_rep.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                finrela   R-squared:                       0.261
# Model:                            OLS   Adj. R-squared:                  0.260
# Method:                 Least Squares   F-statistic:                     903.7
# Date:                Tue, 01 Nov 2022   Prob (F-statistic):          2.56e-170
# Time:                        12:48:10   Log-Likelihood:                -2911.0
# No. Observations:                2564   AIC:                             5826.
# Df Residuals:                    2562   BIC:                             5838.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        2.3904      0.021    111.783      0.000       2.348       2.432
# ...
